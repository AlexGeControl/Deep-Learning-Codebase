# %% [markdown]
# # Fine-tuning InceptionV3 for flowers classification
#
# In this task you will fine-tune InceptionV3 architecture for flowers classification task.
#
# InceptionV3 architecture (https://research.googleblog.com/2016/03/train-your-own-image-classifier-with.html):
# <img src="images/02-c-transfer-learning/01-model-architecture.png" style="width:70%">
#
# Flowers classification dataset (http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) consists of 102 flower categories commonly occurring in the United Kingdom. Each class contains between 40 and 258 images:
# <img src="images/02-c-transfer-learning/02-target-dataset.jpg" style="width:70%">

# %% [markdown]
# # Set Up Session

# %%
# set up environment
import sys
sys.path.append("..")
import grading
import download_utils

# %%
# set up resources:
download_utils.link_all_keras_resources()

# %%
# set up session:
import tensorflow as tf
import keras
from keras import backend as K
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
print(tf.__version__)
print(keras.__version__)
import cv2  # for image processing
from sklearn.model_selection import train_test_split
import scipy.io
import os
import tarfile
import tqdm
import keras_utils
# Out:
# /home/alexge/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# 1.5.0
# 2.1.3

# %%
# !!! remember to clear session/graph if you rebuild your graph to avoid out-of-memory errors !!!
def reset_tf_session():
    K.clear_session()
    tf.reset_default_graph()
    s = K.get_session()
    return s

# %% [markdown]
# # Fill in your Coursera token and email
# To successfully submit your answers to our grader, please fill in your Coursera submission token and email

# %%
grader = grading.Grader(
    assignment_key="2v-uxpD7EeeMxQ6FWsz5LA", 
    all_parts=[
        "wuwwC", 
        "a4FK1", 
        "qRsZ1"
    ]
)

# %% [markdown]
# # Load dataset

# %% [markdown]
# Dataset was downloaded for you, it takes 12 min and 400mb.
# Relevant links (just in case):
# - http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html
# - http://www.robots.ox.ac.uk/~vgg/data/flowers/102/102flowers.tgz
# - http://www.robots.ox.ac.uk/~vgg/data/flowers/102/imagelabels.mat

# %%
# we downloaded them for you, just link them here
download_utils.link_week_3_resources()

# %% [markdown]
# # Prepare images for model

# %%
# we will crop and resize input images to IMG_SIZE x IMG_SIZE
IMG_SIZE = 250

# %%
def decode_image_from_raw_bytes(raw_bytes):
    img = cv2.imdecode(
        np.asarray(
            bytearray(raw_bytes), 
            dtype=np.uint8
        ), 
        1
    )
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img

# %% [markdown]
# We will take a center crop from each image like this:
# <img src="images/02-c-transfer-learning/03-center-crop.jpg" style="width:50%">

# %%
def image_center_crop(img):
    """
    Makes a square center crop of an img, which is a [h, w, 3] numpy array.
    Returns [min(h, w), min(h, w), 3] output with same width and height.
    For cropping use numpy slicing.
    """
    H, W, _ = img.shape
    
    if W > H:
        offset = (W - H) // 2
        img = img[:, offset:(offset + H), :]
    elif H > W:
        offset = (H - W) // 2
        img = img[offset:(offset + W), :, :]
        
    return img

# %%
def prepare_raw_bytes_for_model(raw_bytes, normalize_for_model=True):
    # decode image raw bytes to matrix:
    img = decode_image_from_raw_bytes(raw_bytes)  
    # take squared center crop:
    img = image_center_crop(img)  
    # resize for our model:
    img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))  
    # prepare for normalization:
    if normalize_for_model:
        img = img.astype("float32")  
        img = keras.applications.inception_v3.preprocess_input(img)  # normalize for model
    return img

# %%
# reads bytes directly from tar by filename (slow, but ok for testing, takes ~6 sec)
def read_raw_from_tar(tar_fn, fn):
    with tarfile.open(tar_fn) as f:
        m = f.getmember(fn)
        return f.extractfile(m).read()

# %%
# test cropping
raw_bytes = read_raw_from_tar("102flowers.tgz", "jpg/image_00001.jpg")

img = decode_image_from_raw_bytes(raw_bytes)
print(img.shape)
plt.imshow(img)
plt.show()

img = prepare_raw_bytes_for_model(raw_bytes, normalize_for_model=False)
print(img.shape)
plt.imshow(img)
plt.show()
# Out:
# (500, 591, 3)
# (250, 250, 3)

# %%
## GRADED PART, DO NOT CHANGE!
# Test image preparation for model
prepared_img = prepare_raw_bytes_for_model(read_raw_from_tar("102flowers.tgz", "jpg/image_00001.jpg"))
grader.set_answer("qRsZ1", list(prepared_img.shape) + [np.mean(prepared_img), np.std(prepared_img)])

# %% [markdown]
# # Prepare for training

# %%
# read all filenames and labels for them

# read filenames firectly from tar
def get_all_filenames(tar_fn):
    with tarfile.open(tar_fn) as f:
        return [m.name for m in f.getmembers() if m.isfile()]

all_files = sorted(get_all_filenames("102flowers.tgz"))  # list all files in tar sorted by name
all_labels = scipy.io.loadmat('imagelabels.mat')['labels'][0] - 1  # read class labels (0, 1, 2, ...)
# all_files and all_labels are aligned now
N_CLASSES = len(np.unique(all_labels))
print(N_CLASSES)
# Out:
# 102

# %%
# split into train/test
tr_files, te_files, tr_labels, te_labels = \
    train_test_split(all_files, all_labels, test_size=0.2, random_state=42, stratify=all_labels)

# %%
# will yield raw image bytes from tar with corresponding label
def raw_generator_with_label_from_tar(tar_fn, files, labels):
    label_by_fn = dict(zip(files, labels))
    with tarfile.open(tar_fn) as f:
        while True:
            m = f.next()
            if m is None:
                break
            if m.name in label_by_fn:
                yield f.extractfile(m).read(), label_by_fn[m.name]

# %%
# batch generator
BATCH_SIZE = 64

def batch_generator(items, batch_size):
    """
    Implement batch generator that yields items in batches of size batch_size.
    There's no need to shuffle input items, just chop them into batches.
    Remember about the last batch that can be smaller than batch_size!
    Input: any iterable (list, generator, ...). You should do `for item in items: ...`
        In case of generator you can pass through your items only once!
    Output: In output yield each batch as a list of items.
    """
    batch = []
    for item in items:
        batch.append(item)
        if len(batch) == batch_size:
            yield batch
            batch = []
    
    yield batch

# %%
## GRADED PART, DO NOT CHANGE!
# Test batch generator
def _test_items_generator():
    for i in range(10):
        yield i

grader.set_answer("a4FK1", list(map(lambda x: len(x), batch_generator(_test_items_generator(), 3))))

# %%
def train_generator(files, labels):
    while True:  # so that Keras can loop through this as long as it wants
        for batch in batch_generator(raw_generator_with_label_from_tar(
                "102flowers.tgz", files, labels), BATCH_SIZE):
            # prepare batch images
            batch_imgs = []
            batch_targets = []
            for raw, label in batch:
                img = prepare_raw_bytes_for_model(raw)
                batch_imgs.append(img)
                batch_targets.append(label)
            # stack images into 4D tensor [batch_size, img_size, img_size, 3]
            batch_imgs = np.stack(batch_imgs, axis=0)
            # convert targets into 2D tensor [batch_size, num_classes]
            batch_targets = keras.utils.np_utils.to_categorical(batch_targets, N_CLASSES)
            yield batch_imgs, batch_targets

# %%
# test training generator
for _ in train_generator(tr_files, tr_labels):
    print(_[0].shape, _[1].shape)
    plt.imshow(np.clip(_[0][0] / 2. + 0.5, 0, 1))
    break
# Out:
# (64, 250, 250, 3) (64, 102)

# %% [markdown]
# # Training

# %% [markdown]
# You cannot train such a huge architecture from scratch with such a small dataset.
#
# But using fine-tuning of last layers of pre-trained network you can get a pretty good classifier very quickly.

# %%
# remember to clear session if you start building graph from scratch!
s = reset_tf_session()
# don't call K.set_learning_phase() !!! (otherwise will enable dropout in train/test simultaneously)

# %%
def inception(use_imagenet=True):
    # load pre-trained model graph, don't add final layer
    model = keras.applications.InceptionV3(
        include_top=False, 
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        weights='imagenet' if use_imagenet else None
    )
    # add global pooling just like in InceptionV3
    new_output = keras.layers.GlobalAveragePooling2D()(model.output)
    # add new dense layer for our labels
    new_output = keras.layers.Dense(N_CLASSES, activation='softmax')(new_output)
    model = keras.engine.training.Model(model.inputs, new_output)
    return model

# %%
model = inception()

# %%
model.summary()

# %%
# how many layers our model has
print(len(model.layers))
# Out:
# 313

# %%
# set all layers trainable by default
for layer in model.layers:
    layer.trainable = True
    
# fix deep layers (fine-tuning only last 50)
for layer in model.layers[:-50]:
    layer.trainable = False

# %%
# compile new model
model.compile(
    loss='categorical_crossentropy',  # we train 102-way classification
    optimizer=keras.optimizers.adamax(lr=1e-2),  # we can take big lr here because we fixed first layers
    metrics=['accuracy']  # report accuracy during training
)

# %%
# we will save model checkpoints to continue training in case of kernel death
model_filename = 'flowers.{0:03d}.hdf5'
last_finished_epoch = None

#### uncomment below to continue training from model checkpoint
#### fill `last_finished_epoch` with your latest finished epoch
from keras.models import load_model
s = reset_tf_session()
last_finished_epoch = 171
model = load_model(model_filename.format(last_finished_epoch))

# %% [markdown]
# Training takes **2 hours**. You're aiming for ~0.93 validation accuracy.

# %%
# fine tune for 2 epochs (full passes through all training data)
# we make 2*8 epochs, where epoch is 1/8 of our training data to see progress more often
model.fit_generator(
    train_generator(tr_files, tr_labels), 
    steps_per_epoch=len(tr_files) // BATCH_SIZE // 8,
    epochs=32 * 8,
    validation_data=train_generator(te_files, te_labels), 
    validation_steps=len(te_files) // BATCH_SIZE // 4,
    callbacks=[keras_utils.TqdmProgressCallback(), 
               keras_utils.ModelSaveCallback(model_filename)],
    verbose=0,
    initial_epoch=last_finished_epoch or 0
)
# Out:
# Epoch 1/256
#
# Model saved in flowers.000.hdf5
# Epoch 2/256
#
# Model saved in flowers.001.hdf5
# Epoch 3/256
#
# Model saved in flowers.002.hdf5
# Epoch 4/256
#
# Model saved in flowers.003.hdf5
# Epoch 5/256
#
# Model saved in flowers.004.hdf5
# Epoch 6/256
#
# Model saved in flowers.005.hdf5
# Epoch 7/256
#
# Model saved in flowers.006.hdf5
# Epoch 8/256
#
# Model saved in flowers.007.hdf5
# Epoch 9/256
#
# Model saved in flowers.008.hdf5
# Epoch 10/256
#
# Model saved in flowers.009.hdf5
# Epoch 11/256
#
# Model saved in flowers.010.hdf5
# Epoch 12/256
#
# Model saved in flowers.011.hdf5
# Epoch 13/256
#
# Model saved in flowers.012.hdf5
# Epoch 14/256
#
# Model saved in flowers.013.hdf5
# Epoch 15/256
#
# Model saved in flowers.014.hdf5
# Epoch 16/256
#
# Model saved in flowers.015.hdf5
# Epoch 17/256
#
# Model saved in flowers.016.hdf5
# Epoch 18/256
#
# Model saved in flowers.017.hdf5
# Epoch 19/256
#
# Model saved in flowers.018.hdf5
# Epoch 20/256
#
# Model saved in flowers.019.hdf5
# Epoch 21/256
#
# Model saved in flowers.020.hdf5
# Epoch 22/256
#
# Model saved in flowers.021.hdf5
# Epoch 23/256
#
# Model saved in flowers.022.hdf5
# Epoch 24/256
#
# Model saved in flowers.023.hdf5
# Epoch 25/256
#
# Model saved in flowers.024.hdf5
# Epoch 26/256
#
# Model saved in flowers.025.hdf5
# Epoch 27/256
#
# Model saved in flowers.026.hdf5
# Epoch 28/256
#
# Model saved in flowers.027.hdf5
# Epoch 29/256
#
# Model saved in flowers.028.hdf5
# Epoch 30/256
#
# Model saved in flowers.029.hdf5
# Epoch 31/256
#
# Model saved in flowers.030.hdf5
# Epoch 32/256
#
# Model saved in flowers.031.hdf5
# Epoch 33/256
#
# Model saved in flowers.032.hdf5
# Epoch 34/256
#
# Model saved in flowers.033.hdf5
# Epoch 35/256
#
# Model saved in flowers.034.hdf5
# Epoch 36/256
#
# Model saved in flowers.035.hdf5
# Epoch 37/256
#
# Model saved in flowers.036.hdf5
# Epoch 38/256
#
# Model saved in flowers.037.hdf5
# Epoch 39/256
#
# Model saved in flowers.038.hdf5
# Epoch 40/256
#
# Model saved in flowers.039.hdf5
# Epoch 41/256
#
# Model saved in flowers.040.hdf5
# Epoch 42/256
#
# Model saved in flowers.041.hdf5
# Epoch 43/256
#
# Model saved in flowers.042.hdf5
# Epoch 44/256
#
# Model saved in flowers.043.hdf5
# Epoch 45/256
#
# Model saved in flowers.044.hdf5
# Epoch 46/256
#
# Model saved in flowers.045.hdf5
# Epoch 47/256
#
# Model saved in flowers.046.hdf5
# Epoch 48/256
#
# Model saved in flowers.047.hdf5
# Epoch 49/256
#
# Model saved in flowers.048.hdf5
# Epoch 50/256
#
# Model saved in flowers.049.hdf5
# Epoch 51/256
#
# Model saved in flowers.050.hdf5
# Epoch 52/256
#
# Model saved in flowers.051.hdf5
# Epoch 53/256
#
# Model saved in flowers.052.hdf5
# Epoch 54/256
#
# Model saved in flowers.053.hdf5
# Epoch 55/256
#
# Model saved in flowers.054.hdf5
# Epoch 56/256
#
# Model saved in flowers.055.hdf5
# Epoch 57/256
#
# Model saved in flowers.056.hdf5
# Epoch 58/256
#
# Model saved in flowers.057.hdf5
# Epoch 59/256
#
# Model saved in flowers.058.hdf5
# Epoch 60/256
#
# Model saved in flowers.059.hdf5
# Epoch 61/256
#
# Model saved in flowers.060.hdf5
# Epoch 62/256
#
# Model saved in flowers.061.hdf5
# Epoch 63/256
#
# Model saved in flowers.062.hdf5
# Epoch 64/256
#
# Model saved in flowers.063.hdf5
# Epoch 65/256
#
# Model saved in flowers.064.hdf5
# Epoch 66/256
#
# Model saved in flowers.065.hdf5
# Epoch 67/256
#
# Model saved in flowers.066.hdf5
# Epoch 68/256
#
# Model saved in flowers.067.hdf5
# Epoch 69/256
#
# Model saved in flowers.068.hdf5
# Epoch 70/256
#
# Model saved in flowers.069.hdf5
# Epoch 71/256
#
# Model saved in flowers.070.hdf5
# Epoch 72/256
#
# Model saved in flowers.071.hdf5
# Epoch 73/256
#
# Model saved in flowers.072.hdf5
# Epoch 74/256
#
# Model saved in flowers.073.hdf5
# Epoch 75/256
#
# Model saved in flowers.074.hdf5
# Epoch 76/256
#
# Model saved in flowers.075.hdf5
# Epoch 77/256
#
# Model saved in flowers.076.hdf5
# Epoch 78/256
#
# Model saved in flowers.077.hdf5
# Epoch 79/256
#
# Model saved in flowers.078.hdf5
# Epoch 80/256
#
# Model saved in flowers.079.hdf5
# Epoch 81/256
#
# Model saved in flowers.080.hdf5
# Epoch 82/256
#
# Model saved in flowers.081.hdf5
# Epoch 83/256
#
# Model saved in flowers.082.hdf5
# Epoch 84/256
#
# Model saved in flowers.083.hdf5
# Epoch 85/256
#
# Model saved in flowers.084.hdf5
# Epoch 86/256
#
# Model saved in flowers.085.hdf5
# Epoch 87/256
#
# Model saved in flowers.086.hdf5
# Epoch 88/256
#
# Model saved in flowers.087.hdf5
# Epoch 89/256
#
# Model saved in flowers.088.hdf5
# Epoch 90/256
#
# Model saved in flowers.089.hdf5
# Epoch 91/256
#
# Model saved in flowers.090.hdf5
# Epoch 92/256
#
# Model saved in flowers.091.hdf5
# Epoch 93/256
#
# Model saved in flowers.092.hdf5
# Epoch 94/256
#
# Model saved in flowers.093.hdf5
# Epoch 95/256
#
# Model saved in flowers.094.hdf5
# Epoch 96/256
#
# Model saved in flowers.095.hdf5
# Epoch 97/256
#
# Model saved in flowers.096.hdf5
# Epoch 98/256
#
# Model saved in flowers.097.hdf5
# Epoch 99/256
#
# Model saved in flowers.098.hdf5
# Epoch 100/256
#
# Model saved in flowers.099.hdf5
# Epoch 101/256
#
# Model saved in flowers.100.hdf5
# Epoch 102/256
#
# Model saved in flowers.101.hdf5
# Epoch 103/256
#
# Model saved in flowers.102.hdf5
# Epoch 104/256
#
# Model saved in flowers.103.hdf5
# Epoch 105/256
#
# Model saved in flowers.104.hdf5
# Epoch 106/256
#
# Model saved in flowers.105.hdf5
# Epoch 107/256
#
# Model saved in flowers.106.hdf5
# Epoch 108/256
#
# Model saved in flowers.107.hdf5
# Epoch 109/256
#
# Model saved in flowers.108.hdf5
# Epoch 110/256
#
# Model saved in flowers.109.hdf5
# Epoch 111/256
#
# Model saved in flowers.110.hdf5
# Epoch 112/256
#
# Model saved in flowers.111.hdf5
# Epoch 113/256
#
# Model saved in flowers.112.hdf5
# Epoch 114/256
#
# Model saved in flowers.113.hdf5
# Epoch 115/256
#
# Model saved in flowers.114.hdf5
# Epoch 116/256
#
# Model saved in flowers.115.hdf5
# Epoch 117/256
#
# Model saved in flowers.116.hdf5
# Epoch 118/256
#
# Model saved in flowers.117.hdf5
# Epoch 119/256
#
# Model saved in flowers.118.hdf5
# Epoch 120/256
#
# Model saved in flowers.119.hdf5
# Epoch 121/256
#
# Model saved in flowers.120.hdf5
# Epoch 122/256
#
# Model saved in flowers.121.hdf5
# Epoch 123/256
#
# Model saved in flowers.122.hdf5
# Epoch 124/256
#
# Model saved in flowers.123.hdf5
# Epoch 125/256
#
# Model saved in flowers.124.hdf5
# Epoch 126/256
#
# Model saved in flowers.125.hdf5
# Epoch 127/256
#
# Model saved in flowers.126.hdf5
# Epoch 128/256
#
# Model saved in flowers.127.hdf5
# Epoch 129/256
#
# Model saved in flowers.128.hdf5
# Epoch 130/256
#
# Model saved in flowers.129.hdf5
# Epoch 131/256
#
# Model saved in flowers.130.hdf5
# Epoch 132/256
#
# Model saved in flowers.131.hdf5
# Epoch 133/256
#
# Model saved in flowers.132.hdf5
# Epoch 134/256
#
# Model saved in flowers.133.hdf5
# Epoch 135/256
#
# Model saved in flowers.134.hdf5
# Epoch 136/256
#
# Model saved in flowers.135.hdf5
# Epoch 137/256
#
# Model saved in flowers.136.hdf5
# Epoch 138/256
#
# Model saved in flowers.137.hdf5
# Epoch 139/256
#
# Model saved in flowers.138.hdf5
# Epoch 140/256
#
# Model saved in flowers.139.hdf5
# Epoch 141/256
#
# Model saved in flowers.140.hdf5
# Epoch 142/256
#
# Model saved in flowers.141.hdf5
# Epoch 143/256
#
# Model saved in flowers.142.hdf5
# Epoch 144/256
#
# Model saved in flowers.143.hdf5
# Epoch 145/256
#
# Model saved in flowers.144.hdf5
# Epoch 146/256
#
# Model saved in flowers.145.hdf5
# Epoch 147/256
#
# Model saved in flowers.146.hdf5
# Epoch 148/256
#
# Model saved in flowers.147.hdf5
# Epoch 149/256
#
# Model saved in flowers.148.hdf5
# Epoch 150/256
#
# Model saved in flowers.149.hdf5
# Epoch 151/256
#
# Model saved in flowers.150.hdf5
# Epoch 152/256
#
# Model saved in flowers.151.hdf5
# Epoch 153/256
#
# Model saved in flowers.152.hdf5
# Epoch 154/256
#
# Model saved in flowers.153.hdf5
# Epoch 155/256
#
# Model saved in flowers.154.hdf5
# Epoch 156/256
#
# Model saved in flowers.155.hdf5
# Epoch 157/256
#
# Model saved in flowers.156.hdf5
# Epoch 158/256
#
# Model saved in flowers.157.hdf5
# Epoch 159/256
#
# Model saved in flowers.158.hdf5
# Epoch 160/256
#
# Model saved in flowers.159.hdf5
# Epoch 161/256
#
# Model saved in flowers.160.hdf5
# Epoch 162/256
#
# Model saved in flowers.161.hdf5
# Epoch 163/256
#
# Model saved in flowers.162.hdf5
# Epoch 164/256
#
# Model saved in flowers.163.hdf5
# Epoch 165/256
#
# Model saved in flowers.164.hdf5
# Epoch 166/256
#
# Model saved in flowers.165.hdf5
# Epoch 167/256
#
# Model saved in flowers.166.hdf5
# Epoch 168/256
#
# Model saved in flowers.167.hdf5
# Epoch 169/256
#
# Model saved in flowers.168.hdf5
# Epoch 170/256
#
# Model saved in flowers.169.hdf5
# Epoch 171/256
#
# Model saved in flowers.170.hdf5
# Epoch 172/256

# %%
## GRADED PART, DO NOT CHANGE!
# Accuracy on validation set
test_accuracy = model.evaluate_generator(
    train_generator(te_files, te_labels), 
    len(te_files) // BATCH_SIZE // 2
)[1]
grader.set_answer("wuwwC", test_accuracy)
print(test_accuracy)
# Out:
# 0.4427083333333333

# %%
# token expires every 30 min
COURSERA_TOKEN = '3qKK5JumnXZJ5klD'
COURSERA_EMAIL = '937570601@qq.com'

# %%
# you can make submission with answers so far to check yourself at this stage
grader.submit(COURSERA_EMAIL, COURSERA_TOKEN)

# %% [markdown]
# That's it! Congratulations!
#
# What you've done:
# - prepared images for the model
# - implemented your own batch generator
# - fine-tuned the pre-trained model
